# %%
# %pip install Biopython openai "elasticsearch<8" python-dotenv mistralai fireworks-ai
# %pip install --upgrade pandas

# %% [markdown]
# ## Retrieval

# %%
import os
import json
from elasticsearch import Elasticsearch
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

#Suppress warnings about elasticsearch certificates
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)


def run_elasticsearch_query(query, index=["pubmed", "pubmed_update"]):
    # Retrieve Elasticsearch details from environment variables
    es_host = os.getenv('ELASTICSEARCH_HOST')
    es_user = os.getenv('ELASTICSEARCH_USER')
    es_password = os.getenv('ELASTICSEARCH_PASSWORD')

    # Connect to Elasticsearch
    es = Elasticsearch(
        [es_host],
        http_auth=(es_user, es_password),
        verify_certs=False,  # This will ignore SSL certificate validation
        timeout=60  # Set the timeout to 60 seconds (adjust as needed)
    )

    # Convert the query string to a dictionary
    if isinstance(query, str) and not isinstance(query, dict):
        query_dict = json.loads(query)
    else:
        query_dict = query
    actual_query_string = query_dict["query"]["query_string"]["query"]
    query_dict["query"]["query_string"]["query"] = actual_query_string.replace("/", "\\/")

    # Execute the query
    response = es.search(query_dict, index=index)

    # Process the response to extract the required information
    results = []
    if response['hits']['hits']:
        for hit in response['hits']['hits']:
            result = {
                "id": hit['_id'],
                "title": hit['_source'].get('title', 'No title available'),
                "abstract": hit['_source'].get('abstract', 'No abstract available')
            }
            results.append(result)
    print(f"docs found: {len(results)}")
    return results

#run_elasticsearch_query(expand_query("*"))

# %% [markdown]
# ## Query Expansion

# %%
from openai import OpenAI
import pandas as pd


client = OpenAI()

def expand_query_manual(question:str, model:str) -> str:
    completion = client.chat.completions.create(
        model=model,
        response_format={ "type": "json_object" },
        messages=[
            {"role": "system", "content": "You are BioASQ-GPT, an AI expert in question answering, research, and information retrieval in the biomedical domain."},
             {"role": "user", "content": f"""Turn the following biomedical question into an effective elasticsearch query using the query_string query type 
            by incorporating synonyms and additional terms that closely relate to the main topic and help reduce ambiguity. 
            Focus on maintaining the query's precision and relevance to the original question, the index contains the fields 'title' and 'abstract', return valid json: 
            'Is CircRNA produced by back splicing of exon, intron or both, forming exon or intron circRNA?'"""},
            {"role": "assistant", "content": """
            {
                "query": {
                    "query_string": {
                    "query": "(CircRNA OR \"circular RNA\") AND \"back splicing\" AND (exon OR intron)",
                    "fields": [
                        "title^10",
                        "abstract"
                    ],
                    "default_operator": "AND"
                    }
                },
                "size": 50
                }
            """},
            {"role": "user", "content": f"""Turn the following biomedical question into an effective elasticsearch query using the query_string query type 
            by incorporating synonyms and additional terms that closely relate to the main topic and help reduce ambiguity. 
            Focus on maintaining the query's precision and relevance to the original question, the index contains the fields 'title' and 'abstract', return valid json:
            'Which factor is inhibited by Milvexian?'"""},
            {"role": "assistant", "content": """
             {
                "query": {
                    "query_string": {
                    "query": "Milvexian AND inhibitor AND (factor OR XIa OR FXIa)",
                    "fields": [
                        "title^10",
                        "abstract"
                    ],
                    "default_operator": "AND"
                    }
                },
                "size": 50
                }
            """},
            {"role": "user", "content": f"""Turn the following biomedical question into an effective elasticsearch query using the query_string query type 
            by incorporating synonyms and additional terms that closely relate to the main topic and help reduce ambiguity. 
            Focus on maintaining the query's precision and relevance to the original question, the index contains the fields 'title' and 'abstract', return valid json:
             '{question}'"""},
        ],
        temperature=0.0, # randomness of completion
        logprobs=False,
        seed=90128538
    )
    return completion.choices[0].message.content

def expand_query_few_shot(df_prior, n, question:str, model:str):
    messages = generate_n_shot_examples(df_prior, n)
    # Add the user message
    user_message = {
        "role": "user",
        "content": f"""Turn the following biomedical question into an effective Elasticsearch query using the query_string query type 
        by incorporating synonyms and additional terms that closely relate to the main topic and help reduce ambiguity. 
        Focus on maintaining the query's precision and relevance to the original question, the index contains the fields 'title' and 'abstract', return valid json:
        '{question}'"""
    }
    messages.append(user_message)
    completion = client.chat.completions.create(
        model=model,
        response_format={ "type": "json_object" },
        messages=messages,
        temperature=0.0, # randomness of completion
        logprobs=False,
        seed=90128538
    )
    print(completion)
    return completion.choices[0].message.content


def generate_n_shot_examples(df, n):
    # Sort the DataFrame by 'f1_score' in descending order and select the top n entries
    top_entries = df.sort_values(by='recall', ascending=False).head(n)
    
    # Initialize the system message
    system_message = {"role": "system", "content": "You are BioASQ-GPT, an AI expert in question answering, research, and information retrieval in the biomedical domain."}
    
    # Initialize the list of messages with the system message
    messages = [system_message]
    
    # Loop through each of the top n entries and add the user and assistant messages
    for _, row in top_entries.iterrows():
        question = row['question_body']
        query = row['query']
        
        # Replace problematic characters in question
        question = question.replace("/", "\\\\/")
        
        # Add the user message
        user_message = {
            "role": "user",
            "content": f"""Turn the following biomedical question into an effective Elasticsearch query using the query_string query type 
            by incorporating synonyms and additional terms that closely relate to the main topic and help reduce ambiguity. 
            Focus on maintaining the query's precision and relevance to the original question, the index contains the fields 'title' and 'abstract', return valid json:
            '{question}'"""
        }
        
        # Add the assistant message
        assistant_message = {
            "role": "assistant",
            "content": query  # Assuming 'query' is already in the desired JSON format
        }
        
        messages.extend([user_message, assistant_message])
    
    # Now, messages contains n-shot examples formatted as needed
    # Here you would make your call to the language model using the messages
    # For demonstration, we'll just return the messages
    return messages

# Assuming df is your DataFrame and n is the number of examples you want
# df = pd.read_csv('path_to_your_csv_file.csv')
# n = 5  # For example, taking top 5 entries
# n_shot_examples = generate_n_shot_examples(df, n)
# Now n_shot_examples can be used in your call to the language model

# %% [markdown]
# ### Query Refinement

# %%
def refine_query_with_no_results(question, original_query, model):
    messages = [
        {"role": "system", "content": "You are BioASQ-GPT, an AI expert in question answering, \
            research, and information retrieval in the biomedical domain."},
        {"role": "user", "content": f"""Given that the following search query using the elasticsearch query_string query syntax has returned
        no documents, please generate a broader query that retains the original question's context and relevance.
        Return only the query that can directly be used without any explanation text. 
        Focus on maintaining the query's precision and relevance to the original question. 
        Original question: '{question}', Original query that returned no results: '{original_query}'."""}
    ]

    completion = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0.0, # randomness of completion
        logprobs=False,
        seed=90128538
    )
    return completion.choices[0].message.content

def refine_query_with_relevance_feedback(question, original_query, results, model):
    messages = [
        {"role": "system", "content": "You are BioASQ-GPT, an AI expert in question answering, \
            research, and information retrieval in the biomedical domain."},
        {"role": "user", "content": f"""This search query  ('{original_query}') has returned these results contained in tripple backtics:
         ```{results}```
        The goal is to find documents that help answer this question: '{question}' 
        Create a better query that finds more relevant documents to answer this question.
        Return only the query string that can directly be used without any explanation text."""}
    ]

    completion = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0.0, # randomness of completion
        logprobs=False,
        seed=90128538
    )
    return completion.choices[0].message.content

# %%
import json
import datetime
import pickle
import traceback
import pandas as pd
import os
from concurrent.futures import ThreadPoolExecutor, as_completed

timestamp = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
pickl_file = "state.pkl"
model_name = "gpt-3.5-turbo-0125"
#model_name = "gpt-4-0125-preview"
n_shots = 20



def process_question(df_prior, n, question):
    try:
        print(f"Processing question {question['id']}")

        #query = expand_query_few_shot(df_prior, n, question['body'],model_name)
        query = expand_query_manual(question['body'],model_name)
        query = json.loads(query)
        actual_query_string = query["query"]["query_string"]["query"]
        print(f"Original Query: {actual_query_string}")
        relevant_articles = run_elasticsearch_query(query)
        """
        if len(relevant_articles) == 0:
            actual_query_string = refine_query_with_no_results(question['body'], actual_query_string, model_name)
            query["query"]["query_string"]["query"] = actual_query_string
            print(f"Refined after 0 Query: {actual_query_string}")
            relevant_articles = run_elasticsearch_query(query)
        #actual_query_string = refine_query_with_relevance_feedback(question['body'], actual_query_string, relevant_articles[:5], model_name)
        #query["query"]["query_string"]["query"] = actual_query_string
        print(f"Refined Query: {actual_query_string}")
        relevant_articles = run_elasticsearch_query(query)
        """
            
        relevant_articles_urls = ["http://www.ncbi.nlm.nih.gov/pubmed/"+article['id'] for article in relevant_articles]

        return {
            "question_id": question["id"],
            "question_body": question["body"],
            "question_type": question["type"],
            "query": query,
            "documents": relevant_articles_urls,
            "snippets": []
        }
    except Exception as e:
        print(f"Error processing question {question['id']}: {e}")
        traceback.print_exc()
        return None
    

def save_state(data, file_path=pickl_file):
    """Save the current state to a pickle file."""
    with open(file_path, 'wb') as f:
        pickle.dump(data, f)

def load_state(file_path=pickl_file):
    """Load the state from a pickle file if it exists, otherwise return None."""
    try:
        if os.path.exists(file_path):
            with open(file_path, 'rb') as f:
                return pickle.load(f)
    except EOFError:  # Handles empty pickle file scenario
        return None
    return None

# Define columns
columns = ['question_id', 'question_body', 'question_type', 'query', 'documents', 'snippets']

# Initialize empty DataFrame
questions_df = pd.DataFrame(columns=columns)

# Load the input file in JSON format
input_file_name = './11B2_golden.json'
#input_file_name = './test_queries'
with open(input_file_name) as input_file:
    data = json.loads(input_file.read())

# Assuming 'load_state' returns a DataFrame or None
saved_df = load_state(pickl_file)

if saved_df is not None and not saved_df.empty:
    processed_ids = set(saved_df['question_id'])  # Assuming 'question_id' is your identifier
    questions_df = saved_df
else:
    processed_ids = set()


csv_prior_file_path = './Results/2024-02-21_15-55-52_gpt-4-0125-preview_QueryExpansion_11B1.csv'
df_prior = pd.read_csv(csv_prior_file_path)

# Assuming `data["questions"]` is your list of questions to process
# Filter out questions that have already been processed
questions_to_process = [q for q in data["questions"] if q["id"] not in processed_ids]


# Use ThreadPoolExecutor to process questions in parallel
with ThreadPoolExecutor(max_workers=3) as executor:
    # Dictionary to keep track of question futures
    future_to_question = {executor.submit(process_question, df_prior, n_shots,  q): q for q in questions_to_process}
    
    for future in as_completed(future_to_question):
        question = future_to_question[future]
        try:
            result = future.result()
            if result:
                # Append result to the DataFrame
                result_df = pd.DataFrame([result])
                questions_df = pd.concat([questions_df, result_df], ignore_index=True)
                save_state(questions_df, pickl_file)
        except Exception as e:
            print(f"Error processing question {question['id']}: {e}")
            traceback.print_exc()


# Prefix the output file name with the timestamp
output_file_name = f"./Results/{timestamp}_{model_name}_QueryExpansion_Manual_Refine_Default_And_11B2.csv"

# Ensure the directory exists before saving
os.makedirs(os.path.dirname(output_file_name), exist_ok=True)

questions_df.to_csv(output_file_name, index=False)

# After processing all questions and saving the final output:
try:
    # Check if the pickle file exists before attempting to delete it
    if os.path.exists(pickl_file):
        os.remove(pickl_file)
        print("Intermediate state pickle file deleted successfully.")
except Exception as e:
    print(f"Error deleting pickle file: {e}")
# Out:
# Processing question 63f03006f36125a426000018
# Processing question 641ad941690f196b5100003d
# Processing question 642a029d57b1c7a315000011
# Original Query: (LOQ OR limit of quantification OR LOD OR limit of detection) AND (same OR equal)
# Original Query: ("Histone acetyltransferases" OR HATs OR "acetyltransferases") AND ("acetyl groups" OR acetylation) AND (histones OR lysine) AND purpose
# Original Query: (DESTINY-Breast04 AND Trial) OR (trastuzumab deruxtecan AND breast cancer)
# C:\Users\Samy Ateia\AppData\Roaming\Python\Python312\site-packages\elasticsearch\connection\http_urllib3.py:209: UserWarning: Connecting to https://pragmalingu.de:9200 using SSL with verify_certs=False is insecure.
#   warnings.warn(
# C:\Users\Samy Ateia\AppData\Local\Temp\ipykernel_73372\3659210096.py:37: DeprecationWarning: Using positional arguments for APIs is deprecated and will be disabled in 8.0.0. Instead use only keyword arguments for all APIs. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   response = es.search(query_dict, index=index)
# docs found: 50
# docs found: 35
# docs found: 50
# Refined Query: '(DESTINY-Breast04 AND Trial) OR (trastuzumab deruxtecan AND breast cancer AND results)'
# docs found: 50
# Processing question 6432fc0457b1c7a31500001f
# Refined Query: '(LOQ OR limit of quantification) AND (LOD OR limit of detection) AND (same OR equal OR identical OR equivalent)'
# Refined Query: ('Histone acetyltransferases' OR HATs OR 'acetyltransferases') AND ('acetyl groups' OR acetylation) AND (histones OR lysine) AND 'purpose of acetylation transfer'
# docs found: 3
# Processing question 64178edb690f196b51000025
# docs found: 50
# Processing question 6402bf2b201352f04a000007
# Original Query: (hereditary angioedema) AND (mutated OR mutation) AND (gene OR genetic)
# docs found: 50
# Original Query: (casimersen OR SRP-4045) AND mechanism AND action
# docs found: 1
# Refined Query: '(hereditary angioedema) AND (mutated OR mutation) AND (gene OR genetic) AND (most frequently mutated)'
# Original Query: (tiragolumab OR MTIG7192A) AND mechanism AND action
# docs found: 0
# docs found: 13
# Processing question 641d8fd6690f196b51000041
# Refined Query: '(casimersen OR SRP-4045) AND mechanism of action'
# docs found: 1
# Processing question 6429d5c557b1c7a315000006
# Refined after 0 Query: (tiragolumab OR MTIG7192A) AND mechanism AND action OR function OR mode of action OR how it works
# docs found: 0
# Refined Query: (tiragolumab OR MTIG7192A) AND "mechanism of action"
# docs found: 0
# Processing question 6433012b57b1c7a315000022
# Original Query: (serum biomarkers OR blood biomarkers OR circulating biomarkers) AND (Neuromyelitis Optica Spectrum Disorders OR NMOSD) AND (disease activity monitoring OR disease progression)
# docs found: 5
# Original Query: (thrombotic OR clotting) AND complications AND (COVID-19 OR SARS-CoV-2)
# docs found: 50
# Original Query: Cinryze OR C1 inhibitor esterase OR C1-INH concentrate
# Refined Query: '(serum biomarkers OR blood biomarkers OR circulating biomarkers) AND (Neuromyelitis Optica Spectrum Disorders OR NMOSD) AND (disease activity monitoring OR disease progression) AND (proposed OR identified OR potential)'
# Refined Query: '(thrombotic OR clotting) AND complications AND (COVID-19 OR SARS-CoV-2) AND major'
# docs found: 50
# docs found: 2
# Processing question 64179337690f196b51000034
# Refined Query: ('Cinryze' OR 'C1-esterase inhibitor' OR 'C1-INH concentrate') AND ('hereditary angioedema' OR 'bradykinin' OR 'subcutaneous attacks')
# Original Query: (machine learning OR computational intelligence OR artificial intelligence) AND (statistical methods OR traditional methods) AND (survival analysis OR survival prediction)
# docs found: 50
# Processing question 63f03c47f36125a42600001e
# docs found: 50
# Processing question 642c82c557b1c7a315000012
# docs found: 21
# Refined Query: '(machine learning OR computational intelligence OR artificial intelligence) AND (survival analysis OR survival prediction) AND (outperform OR superior OR comparison)'
# Original Query: (ZF2001 OR "ZF 2001") AND (treatment OR therapy OR indication OR disease)
# docs found: 21
# docs found: 50
# Processing question 6429b41757b1c7a315000004
# Original Query: (mammal OR animal) AND (lowest OR fewest) AND (chromosome OR karyotype) AND number
# docs found: 50
# Refined Query: '(ZF2001 OR "ZF 2001") AND (used OR indicated OR treatment OR therapy OR disease)'
# docs found: 28
# Processing question 643305b257b1c7a315000025
# Refined Query: '(mammal OR animal) AND "lowest chromosome number"'
# docs found: 1
# Processing question 641635fa690f196b5100001c
# Original Query: (histone AND modification) AND (acetyl OR methyl) AND (activating OR repressing) AND (acetyltransferases OR methyltransferases) AND (amino acids OR residues)
# Original Query: (Ruconest OR conestat alfa) AND company
# docs found: 50
# docs found: 50
# Original Query: (Duchenne muscular dystrophy OR DMD) AND (age OR diagnosis)
# Refined Query: '(Ruconest OR conestat alfa) AND produces'
# docs found: 50
# docs found: 50
# Processing question 6402c868201352f04a00000b
# Refined Query: '(histone AND modification) AND (acetyl OR methyl) AND (activating OR repressing) AND (histone acetyltransferases OR histone methyltransferases) AND (amino acids)'
# Refined Query: '(Duchenne muscular dystrophy OR DMD) AND "age of diagnosis"'
# docs found: 44
# Processing question 6424154d690f196b5100004a
# docs found: 35
# Processing question 64299b6a57b1c7a315000001
# Original Query: (erythropoietin OR EPO) AND (optic neuritis) AND (TONE trial)
# docs found: 3
# Original Query: (R value OR correlation coefficient) AND hepatoxicity
# docs found: 0
# Refined Query: '(erythropoietin OR EPO) AND (optic neuritis) AND (TONE trial) AND (efficacy OR effectiveness)'
# docs found: 3
# Processing question 6432ffdf57b1c7a315000021
# Refined after 0 Query: "(R value OR correlation coefficient OR correlation) AND hepatoxicity"
# Original Query: (COVID-19 OR SARS-CoV-2 OR coronavirus) AND (Omicron OR B.1.1.529) AND (severe OR severity) AND (variant OR strain)
# docs found: 0
# docs found: 50
# Refined Query: "(Pearson correlation OR Spearman correlation OR R value) AND hepatoxicity"
# docs found: 0
# Processing question 64178ec2690f196b51000024
# Original Query: (hereditary angioedema OR HAE OR Quincke's edema OR familial angioneurotic edema)
# Refined Query: ('(COVID-19 OR SARS-CoV-2 OR coronavirus) AND (Omicron OR B.1.1.529) AND (severity OR severe) AND (clinical outcomes OR morbidity OR mortality)')
# docs found: 50
# docs found: 50
# Processing question 64040bd8201352f04a00000e
# Refined Query: '(hereditary angioedema)'
# Original Query: (viltolarsen OR NS-065/NCNP-01) AND (mechanism OR action)
# docs found: 5
# docs found: 50
# Processing question 6422e7f0690f196b51000045
# Refined Query: '(viltolarsen OR NS-065/NCNP-01) AND "mechanism of action"'
# docs found: 2
# Processing question 6429ee7457b1c7a31500000b
# Original Query: (bexarotene OR Targretin) AND (relapsing-remitting multiple sclerosis OR RRMS)
# docs found: 1
# Refined Query: '(bexarotene OR Targretin) AND (multiple sclerosis AND efficacy)'
# docs found: 2
# Processing question 6433050157b1c7a315000024
# Original Query: (analgesics OR painkillers OR antipyretics OR fever reducers) AND (side effects OR adverse effects) AND (COVID-19 vaccination OR SARS-CoV-2 vaccination)
# Original Query: (recombinant OR bioengineered) AND (human C1 inhibitor OR C1INH) AND (acute attacks OR hereditary angioedema OR HAE) AND drug
# docs found: 50
# docs found: 23
# Refined Query: '(analgesics OR antipyretics) AND (side effects OR adverse effects) AND (COVID-19 vaccination OR SARS-CoV-2 vaccination)'
# Refined Query: '(recombinant OR bioengineered) AND (human C1 inhibitor OR C1INH) AND (acute attacks OR hereditary angioedema OR HAE) AND (first OR initial) AND (treatment OR drug)'
# docs found: 7
# Processing question 6417900b690f196b5100002a
# docs found: 18
# Processing question 63f57ea133942b094c000005
# Original Query: (viltolarsen OR NS-065/NCNP-01) AND (Duchenne Muscular Dystrophy OR DMD) AND (treatment OR therapy)
# docs found: 25
# Original Query: ("Cat eye syndrome" OR "Schmid-Fraccaro syndrome") AND triad
# docs found: 5
# Refined Query: '(viltolarsen OR NS-065/NCNP-01) AND (Duchenne Muscular Dystrophy OR DMD) AND (exon 53 skipping)'
# Refined Query: ('("Cat eye syndrome" OR "Schmid-Fraccaro syndrome") AND "clinical triad"')
# docs found: 16
# Processing question 64281a47690f196b5100004f
# docs found: 3
# Processing question 6429cfb557b1c7a315000005
# Original Query: (OXLUMO OR lumasiran) AND (treatment OR therapy) AND (primary hyperoxaluria OR PH)
# docs found: 33
# Original Query: (inhaled glucocorticoids OR corticosteroids) AND (asthma OR COPD) AND (stop OR discontinue) AND (COVID-19 OR coronavirus)
# docs found: 4
# Refined Query: '(OXLUMO OR lumasiran) AND "primary hyperoxaluria" AND (treatment OR therapy)'
# docs found: 33
# Processing question 6432f75757b1c7a31500001d
# Original Query: (Zanubrutinib OR BGB-3111) AND (first-generation OR first generation) AND (BTK inhibitor OR Bruton's tyrosine kinase inhibitor) AND (approved OR approval) AND (US OR United States) AND (Food and Drug Administration OR FDA)
# docs found: 0
# Refined Query: '(inhaled glucocorticoids OR corticosteroids) AND (asthma OR COPD) AND (COVID-19 OR coronavirus) AND (continue OR maintain)'
# Refined after 0 Query: (Zanubrutinib OR BGB-3111) AND ("BTK inhibitor" OR "Bruton's tyrosine kinase inhibitor") AND (approved OR approval) AND ("US Food and Drug Administration" OR FDA)
# docs found: 17
# docs found: 45
# Processing question 64178fea690f196b51000028
# Refined Query: '(Zanubrutinib OR BGB-3111) AND ("BTK inhibitor" OR "Bruton\'s tyrosine kinase inhibitor") AND ("first-generation" OR "second-generation") AND ("US Food and Drug Administration" OR FDA)'
# docs found: 8
# Processing question 63eef94ff36125a426000010
# Original Query: (eteplirsen AND DMD) OR (eteplirsen AND Duchenne muscular dystrophy)
# docs found: 50
# Original Query: (Cinpanemab OR antibody) AND (Parkinson's Disease OR Parkinson Disease)
# Refined Query: '(eteplirsen AND DMD) OR (eteplirsen AND Duchenne muscular dystrophy) OR (eteplirsen AND Becker muscular dystrophy) OR (eteplirsen AND exon skipping mutations)'
# docs found: 50
# docs found: 50
# Processing question 6426d131690f196b5100004e
# Refined Query: '(Cinpanemab AND Parkinson\'s Disease) AND (clinical trial OR efficacy OR biomarker OR immunotherapy)'
# docs found: 6
# Processing question 6429e17657b1c7a315000007
# Original Query: (Ashwell receptor OR asialoglycoprotein receptor) AND organ
# docs found: 4
# Refined Query: '(Ashwell receptor OR asialoglycoprotein receptor) AND location'
# docs found: 1
# Processing question 643306cc57b1c7a315000027
# Original Query: (histone marks OR histone modifications OR histone methylation OR histone acetylation) AND enhancers AND chromatin AND cell
# docs found: 50
# Refined Query: '(histone marks OR histone modifications OR histone methylation OR histone acetylation) AND enhancers AND chromatin AND cell AND indicative'
# docs found: 50
# Processing question 64178ffb690f196b51000029
# Original Query: (casimersen OR SRP-4045) AND (Duchenne muscular dystrophy OR DMD) AND (treatment OR therapy)
# Original Query: (CRISPR/Cas12a OR CRISPR OR Cas12a) AND (detection OR detect) AND (EGFR AND mutations) AND (circulating DNA OR ctDNA)
# docs found: 6
# docs found: 11
# Refined Query: '(CRISPR/Cas12a OR CRISPR OR Cas12a) AND (detection OR detect) AND (EGFR AND mutations) AND (circulating DNA OR ctDNA)'
# Refined Query: '(casimersen OR SRP-4045) AND (Duchenne muscular dystrophy) AND (exon 45 skipping)'
# docs found: 6
# Processing question 63eeefc5f36125a426000009
# docs found: 5
# Processing question 6415b422690f196b5100000a
# Original Query: CIS43LS AND target
# Original Query: (Cal-light OR Cal light) AND function
# docs found: 2
# docs found: 50
# Refined Query: ('CIS43LS AND target') OR ('CIS43LS target') OR ('CIS43LS AND target molecule') OR ('CIS43LS target protein')
# docs found: 2
# Processing question 64172bb2690f196b5100001e
# Refined Query: '(Cal-light OR "Cal-Light" OR "Cal light") AND function AND "what does Cal-light do"'
# docs found: 0
# Processing question 63f9ccdc33942b094c00000f
# Original Query: (RNA polymerase OR transcription enzyme) AND (gene region OR gene locus OR gene site) AND (transcription initiation OR transcription start)
# Original Query: (PRP-40 OR PRP40 OR "pre-mRNA processing factor 40") AND (microexon OR "micro-exon") AND splicing
# docs found: 1
# Refined Query: ('(PRP-40 OR PRP40 OR "pre-mRNA processing factor 40") AND (microexon OR "micro-exon") AND splicing')
# docs found: 1
# Processing question 641790d6690f196b5100002d
# docs found: 50
# Refined Query: '(RNA polymerase AND bind AND transcription initiation AND gene region)'
# docs found: 50
# Processing question 6404199d201352f04a000019
# Original Query: ("loss of independent ambulation" OR "loss of walking ability") AND (Duchenne OR DMD) AND (age OR ages OR range)
# docs found: 14
# Original Query: (ocrelizumab OR Ocrevus) AND (primary progressive multiple sclerosis OR PPMS)
# docs found: 50
# Refined Query: ('("loss of independent ambulation" OR "loss of walking ability") AND (Duchenne OR DMD) AND ("age of onset" OR "age at onset" OR "age range" OR "age of occurrence" OR "age at which" OR "age when")')
# Refined Query: '(ocrelizumab OR Ocrevus) AND "primary progressive multiple sclerosis" AND effective'
# docs found: 45
# Processing question 641b7bba690f196b5100003e
# docs found: 4
# Processing question 6428da74690f196b51000052
# Original Query: (Indocyanine green OR ICG) AND (use OR application OR function)
# Original Query: (transcripts OR mRNA OR RNA) AND (generation OR production OR synthesis) AND (gene OR genomic)
# docs found: 50
# docs found: 50
# Refined Query: '(transcripts OR mRNA OR RNA) AND (generation OR production OR synthesis) AND (multiple OR alternative OR different) AND (gene OR genomic)'
# docs found: 50
# Processing question 63f9cdcc33942b094c000013
# Original Query: (silencing OR knockdown) AND SRRM4 AND (inhibit OR suppress) AND (tumor growth OR tumour growth) AND cancers
# docs found: 1
# Refined Query: '(silencing OR knockdown) AND SRRM4 AND (inhibit OR suppress) AND (tumor growth OR tumour growth) AND cancers'
# docs found: 1
# Processing question 64179aac690f196b51000037
# Original Query: (Duchenne muscular dystrophy OR DMD) AND (life expectancy OR survival rate OR prognosis)
# docs found: 50
# Refined Query: '(Duchenne muscular dystrophy OR DMD) AND (life expectancy OR survival rate OR prognosis)'
# docs found: 50
# Processing question 64041e97201352f04a00001e
# Error processing question 6422e7f0690f196b51000045: Expecting ',' delimiter: line 4 column 137 (char 179)
# Processing question 6422ee03690f196b51000046
# Traceback (most recent call last):
#   File "C:\Users\Samy Ateia\AppData\Local\Temp\ipykernel_73372\655031348.py", line 23, in process_question
#     query = json.loads(query)
#             ^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python312\Lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python312\Lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python312\Lib\json\decoder.py", line 353, in raw_decode
#     obj, end = self.scan_once(s, idx)
#                ^^^^^^^^^^^^^^^^^^^^^^
# json.decoder.JSONDecodeError: Expecting ',' delimiter: line 4 column 137 (char 179)
# Original Query: (cells OR cell types) AND produce AND erythroferrone
# docs found: 7
# Refined Query: '(cells OR cell types) AND produce AND erythroferrone'
# docs found: 7
# Processing question 6429f86657b1c7a31500000d
# Original Query: (Mediator OR transcriptional mediator) AND (gene expression OR transcription regulation)
# docs found: 50
# Refined Query: '(Mediator OR transcriptional mediator) AND (gene expression OR transcription regulation)'
# docs found: 50
# Processing question 6415c0df690f196b51000010
# Original Query: (FBDD OR 'Fragment-Based Drug Discovery')
# docs found: 50
# Refined Query: '(FBDD OR "Fragment-Based Drug Discovery")'
# docs found: 50
# Processing question 64041dae201352f04a00001d
# Original Query: (deucravacitinib OR BMS-986165) AND (efficacy OR effectiveness) AND psoriasis
# docs found: 50
# Refined Query: '(deucravacitinib OR BMS-986165) AND (efficacy OR effectiveness) AND (psoriasis AND clinical trial)'
# docs found: 31
# Processing question 6415b6eb690f196b5100000b
# Original Query: (orexin OR hypocretin OR "orexin/hypocretin") AND neurons AND regulate AND processes
# docs found: 50
# Refined Query: '(orexin OR hypocretin OR "orexin/hypocretin") AND neurons AND regulate AND functions'
# docs found: 50
# Processing question 6428da47690f196b51000051
# Original Query: (epigenetic OR chromatin modification OR DNA methylation) AND (introns OR intronic regions) AND (gene expression OR transcription regulation)
# docs found: 50
# Refined Query: '(epigenetic status OR DNA methylation OR chromatin modification) AND (introns AND gene expression)'
# docs found: 50
# Processing question 6415c5d4690f196b51000014
# Original Query: (Keytruda OR pembrolizumab) AND (originally approved OR initial approval) AND FDA
# docs found: 10
# Refined Query: '(Keytruda OR pembrolizumab) AND "first approved" AND "FDA"'
# docs found: 6
# Processing question 63f5713733942b094c000003
# Original Query: (Achard-Thiers syndrome) AND (clinical features OR symptoms OR manifestations)
# docs found: 3
# Refined Query: '(Achard-Thiers syndrome) AND (clinical features OR symptoms OR manifestations OR signs)'
# docs found: 3
# Processing question 642d4c9b57b1c7a315000013
# Original Query: (Luminopsins OR fusion proteins) AND (luminol OR Rhodopsin)
# docs found: 50
# Refined Query: '(Luminopsins AND fusion proteins) AND (luminol OR Rhodopsin)'
# docs found: 0
# Processing question 6429fe4e57b1c7a31500000f
# Original Query: (coactivators OR coactivator proteins OR transcriptional coactivators)
# docs found: 50
# Refined Query: '(coactivators OR coactivator proteins OR transcriptional coactivators) AND "What are coactivators?"'
# docs found: 1
# Processing question 6412331b201352f04a000038
# Original Query: (PROTACs OR 'Proteolysis Targeting Chimeras')
# docs found: 50
# Refined Query: (PROTACs OR "Proteolysis Targeting Chimeras") AND "What are PROTACs?"
# docs found: 0
# Processing question 62008022c9dfcb9c0900001b
# Original Query: (ALBI grade) AND (variables OR parameters)
# docs found: 50
# Refined Query: '(ALBI grade) AND (variables OR parameters) AND ("included in")'
# docs found: 44
# Processing question 64240f33690f196b51000049
# Original Query: (FIP OR 'Feline Infectious Peritonitis') AND (treatment OR drugs OR therapy)
# docs found: 50
# Refined Query: '(FIP OR 'Feline Infectious Peritonitis') AND (treatment OR drugs OR therapy) AND (prednisone OR cyclophosphamide OR glucocorticoids OR immune modulators)'
# docs found: 31
# Processing question 6428da98690f196b51000053
# Original Query: (COVID-19 OR SARS-CoV-2 OR "coronavirus disease 2019") AND (respiratory illness OR respiratory infection OR influenza) AND (distinguish OR differentiate OR clinical)
# Error processing question 64041e97201352f04a00001e: Expecting ',' delimiter: line 4 column 141 (char 183)
# Processing question 6415c8f1690f196b51000017
# Traceback (most recent call last):
#   File "C:\Users\Samy Ateia\AppData\Local\Temp\ipykernel_73372\655031348.py", line 23, in process_question
#     query = json.loads(query)
#             ^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python312\Lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python312\Lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python312\Lib\json\decoder.py", line 353, in raw_decode
#     obj, end = self.scan_once(s, idx)
#                ^^^^^^^^^^^^^^^^^^^^^^
# json.decoder.JSONDecodeError: Expecting ',' delimiter: line 4 column 141 (char 183)
# docs found: 50
# Refined Query: ('(COVID-19 OR SARS-CoV-2 OR "coronavirus disease 2019") AND (respiratory illness OR respiratory infection OR influenza) AND (distinguish OR differentiate OR clinical)')
# Original Query: (paclitaxel OR Taxol OR docetaxel OR Taxotere OR doxorubicin OR epirubicin) AND (cancer OR carcinoma)
# docs found: 50
# Processing question 63eeec79f36125a426000006
# docs found: 50
# Refined Query: '(paclitaxel OR Taxol OR docetaxel OR Taxotere OR doxorubicin OR epirubicin) AND (approved AND cancer)'
# docs found: 50
# Processing question 642321a5690f196b51000047
# Original Query: (Talquetamab OR JNJ-64407564) AND (treatment OR therapy OR management) AND (disease OR condition)
# docs found: 3
# Refined Query: '(Talquetamab OR JNJ-64407564) AND (treatment OR therapy OR management) AND (multiple myeloma)'
# docs found: 19
# Processing question 6428d7da690f196b51000050
# Original Query: (Feline Spongiform Encephalopathy OR FSE) AND summarize
# docs found: 2
# Refined Query: '(Indocyanine green OR ICG) AND (use OR application OR function OR role OR utilization OR employed OR employed OR employed OR implement OR implementing OR implementing OR employed OR employing OR employing OR employing OR employed OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR
# Refined Query: '(Feline Spongiform Encephalopathy OR FSE) AND summary'
# Error processing question 641b7bba690f196b5100003e: RequestError(400, 'search_phase_execution_exception', "Failed to parse query ['(Indocyanine green OR ICG) AND (use OR application OR function OR role OR utilization OR employed OR employed OR employed OR implement OR implementing OR implementing OR employed OR employing OR employing OR employing OR employed OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR]")
# Processing question 63f9cbb433942b094c00000c
# Traceback (most recent call last):
#   File "C:\Users\Samy Ateia\AppData\Local\Temp\ipykernel_73372\655031348.py", line 35, in process_question
#     relevant_articles = run_elasticsearch_query(query)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Samy Ateia\AppData\Local\Temp\ipykernel_73372\3659210096.py", line 37, in run_elasticsearch_query
#     response = es.search(query_dict, index=index)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Samy Ateia\AppData\Roaming\Python\Python312\site-packages\elasticsearch\client\utils.py", line 347, in _wrapped
#     return func(*args, params=params, headers=headers, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Samy Ateia\AppData\Roaming\Python\Python312\site-packages\elasticsearch\client\__init__.py", line 1821, in search
#     return self.transport.perform_request(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Samy Ateia\AppData\Roaming\Python\Python312\site-packages\elasticsearch\transport.py", line 466, in perform_request
#     raise e
#   File "C:\Users\Samy Ateia\AppData\Roaming\Python\Python312\site-packages\elasticsearch\transport.py", line 427, in perform_request
#     status, headers_response, data = connection.perform_request(
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Samy Ateia\AppData\Roaming\Python\Python312\site-packages\elasticsearch\connection\http_urllib3.py", line 291, in perform_request
#     self._raise_error(response.status, raw_data)
#   File "C:\Users\Samy Ateia\AppData\Roaming\Python\Python312\site-packages\elasticsearch\connection\base.py", line 328, in _raise_error
#     raise HTTP_EXCEPTIONS.get(status_code, TransportError)(
# elasticsearch.exceptions.RequestError: RequestError(400, 'search_phase_execution_exception', "Failed to parse query ['(Indocyanine green OR ICG) AND (use OR application OR function OR role OR utilization OR employed OR employed OR employed OR implement OR implementing OR implementing OR employed OR employing OR employing OR employing OR employed OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR utilized OR]")
# docs found: 0
# Processing question 61fa941ec9dfcb9c09000005
# Original Query: (untranslated regions OR UTRs OR 5' UTR OR 3' UTR) AND regulate AND gene expression
# docs found: 50
# Original Query: (alternative splicing OR splicing variants) AND (heart disease OR cardiovascular disease)
# Original Query: (Intepirdine OR RVT-101) AND (Alzheimer's disease OR AD) AND (use OR treatment)
# docs found: 7
# Refined Query: '(untranslated regions OR UTRs OR 5\' UTR OR 3\' UTR) AND regulate AND gene expression'
# docs found: 50
# docs found: 50
# Processing question 6422e2f1690f196b51000043
# Refined Query: '(alternative splicing AND heart disease)'
# Refined Query: '(Intepirdine OR RVT-101) AND (Alzheimer\'s disease OR AD) AND (efficacy OR clinical trial OR review)'
# docs found: 50
# Processing question 64299fa957b1c7a315000002
# docs found: 4
# Processing question 6432fb1957b1c7a31500001e
# Original Query: (Gal-Nac OR GalNAc OR Gal N-acetylglucosamine) AND (siRNA OR ASO OR antisense oligonucleotide) AND (human cells OR cells OR cell types)
# docs found: 1
# Original Query: (rebound AND COVID-19) OR (recurrent AND COVID-19) OR (resurgence AND COVID-19)
# docs found: 50
# Original Query: (Zanubrutinib OR BGB-3111) AND (clinical applications OR indications) AND (approved OR approval) AND "United States"
# docs found: 4
# Refined Query: ('(Gal-Nac OR GalNAc OR Gal N-acetylglucosamine) AND (siRNA OR ASO OR antisense oligonucleotide) AND (human cells OR cells OR cell types) AND (targeted OR uptake OR delivery)')
# docs found: 1Refined Query: '(rebound AND COVID-19) OR (recurrent AND COVID-19) OR (resurgence AND COVID-19) OR (viral relapse AND COVID-19)'
#
# Processing question 61f7cb37882a024a10000029
# docs found: 50
# Processing question 6413712a201352f04a00003e
# Refined Query: '(Zanubrutinib OR BGB-3111) AND (clinical applications OR indications) AND (approved OR approval) AND "United States" AND "mantle cell lymphoma" AND "Waldenström macroglobulinemia" AND "marginal zone lymphoma" AND "relapsed or refractory"'
# docs found: 1
# Processing question 6429ad3857b1c7a315000003
# Original Query: (1p19q co-deletion OR 1p/19q codeletion OR 1p and 19q co-deletion) AND (tumors OR tumours OR neoplasms)
# docs found: 10
# Original Query: (X-inactive specific transcript OR Xist) AND (gene OR encoding)
# docs found: 50
# Refined Query: '(1p19q co-deletion OR 1p/19q codeletion OR 1p and 19q co-deletion) AND (tumors OR tumours OR neoplasms) AND (associated with)'
# Refined Query: '(X-inactive specific transcript OR Xist) AND (gene OR encodes) AND (function OR role OR encode)'
# Original Query: (rilonacept OR IL-1 Trap) AND (pericarditis OR pericardial inflammation)
# docs found: 4
# Processing question 63f92fd033942b094c00000b
# docs found: 50
# Processing question 64041f38201352f04a00001f
# docs found: 50
# Original Query: (microexons OR "micro-exons" OR "small exons")
# docs found: 50
# Refined Query: '(rilonacept OR IL-1 Trap) AND (pericarditis)'
# Original Query: (tebentafusp OR IMCgp100) AND (efficacy OR effectiveness OR treatment) AND (uveal melanoma OR ocular melanoma)
# Refined Query: '(microexons OR "micro-exons" OR "small exons" OR "very short exons")'
# docs found: 35
# Processing question 6426bb49690f196b5100004d
# docs found: 50
# docs found: 50
# Refined Query: '(tebentafusp OR IMCgp100) AND (efficacy OR effectiveness) AND (uveal melanoma)'
# docs found: 23
# Original Query: (Fenton reaction) OR (Fenton chemistry) OR (Fenton process)
# docs found: 50
# Refined Query: '(Fenton reaction) OR (Fenton chemistry) OR (Fenton process) OR (Fenton reaction mechanism)'
# docs found: 50
# Intermediate state pickle file deleted successfully.

# %% [markdown]
# ### Generate Run File

# %%
import pandas as pd
import json

def csv_to_json(csv_filepath, json_filepath):
    # Step 1: Read the CSV file into a pandas DataFrame
    df = pd.read_csv(csv_filepath)
    
    # Transform the DataFrame into a list of dictionaries, one per question
    questions_list = df.to_dict(orient='records')
    
    # Initialize the structure of the JSON file
    json_structure = {"questions": []}
    
    # Step 2: Transform the DataFrame into the desired JSON structure
    for item in questions_list:
        question_dict = {
            "documents": item["documents"].strip("[]").replace("'", "").split(", "),
            "snippets": [],  # Assuming snippets are to be filled in manually or from another source
            "body": item["question_body"],
            "type": item["question_type"],
            "id": item["question_id"],
            # "ideal_answer" and "exact_answer" are placeholders; assuming they're to be added
            "ideal_answer": [],
            "exact_answer": ""
        }
        json_structure["questions"].append(question_dict)
    
    # Step 3: Write the JSON structure to a file
    with open(json_filepath, 'w', encoding='utf-8') as json_file:
        json.dump(json_structure, json_file, ensure_ascii=False, indent=4)

# Example usage
csv_filepath = './Results/2024-02-21_10-07-09_gpt-3.5-turbo-0125_QueryExpansion_11B1.csv'  # Update this path to your actual CSV file path
json_filepath = './Results/2024-02-21_10-07-09_gpt-3.5-turbo-0125_QueryExpansion_11B1_BioASQ-Run.json'  # Update this path to where you want to save the JSON file
csv_to_json(csv_filepath, json_filepath)
